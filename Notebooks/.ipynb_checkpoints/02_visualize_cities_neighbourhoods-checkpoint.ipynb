# %%
import pandas as pd
import numpy as np
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from geopy.geocoders import Nominatim


CLIENT_ID='ZGY023E0IAYOYCPVCKZV3LRG5LTTWEBFMJ2KAYEIZU22ZSWL'
CLIENT_SECRET='XYUFKB5RICTULFGMCT2CIL54OWNN4B2D1QQ1O0PQVNJ34PWV'
VENU_KEY='fsq3ZvwbThl+Fk13tHHRPsLUDh5Mp1mxVvNVGwdzaCyOJh4='

# %%
df = pd.read_csv('../data/df_with_lat_long.csv')

# %%
df
# Out:
#                   Neighbourhood         City        Country   Latitude  \
# 0    Charlottenburg-Wilmersdorf       Berlin        Germany  52.507856
# 1      Friedrichshain-Kreuzberg       Berlin        Germany  52.501115
# 2                   Lichtenberg       Berlin        Germany  52.532161
# 3           Marzahn-Hellersdorf       Berlin        Germany  52.522523
# 4                         Mitte       Berlin        Germany  52.517885
# ..                          ...          ...            ...        ...
# 157              READ BLVD EAST  New Orleans  United States  30.031682
# 158            WEST LAKE FOREST  New Orleans  United States  42.221968
# 159                LITTLE WOODS  New Orleans  United States  30.075200
# 160                 FAIRGROUNDS  New Orleans  United States  29.983767
# 161                   IBERVILLE  New Orleans  United States  29.981962
#
#      Longitude
# 0    13.263952
# 1    13.444285
# 2    13.511893
# 3    13.587663
# 4    13.404060
# ..         ...
# 157 -89.975295
# 158 -87.873126
# 159 -89.944235
# 160 -90.081270
# 161 -90.109340
#
# [162 rows x 5 columns]

# %%
def get_lat_long(address):
    geolocator = Nominatim(user_agent="Get_Geo_Codes")
    location = geolocator.geocode(address)
    if location is not None:
        lat_ =location.latitude
        long_ = location.longitude
    else:
        lat_ =long_ = None
        
    return lat_,long_

# %%
cities = list(df['City'].unique())
cities
# Out:
# ['Berlin', 'Alberta', 'New Orleans']

# %%
city_point={}
arr=[]
for city in cities:
    lat_ , long_ =get_lat_long(city)
    city_point['City']=city ;city_point['lat']=lat_ ;city_point['long']=long_
    arr.append(city_point)
    city_point={}

# %%
arr
# Out:
# [{'City': 'Berlin', 'lat': 52.5170365, 'long': 13.3888599},
#  {'City': 'Alberta', 'lat': 55.001251, 'long': -115.002136},
#  {'City': 'New Orleans', 'lat': 29.9759983, 'long': -90.0782127}]

# %%
df_city=pd.DataFrame(arr)
df_city
# Out:
#           City        lat        long
# 0       Berlin  52.517037   13.388860
# 1      Alberta  55.001251 -115.002136
# 2  New Orleans  29.975998  -90.078213

# %%
city_map = folium.Map(location = [0,0], zoom_start = 2)

for lat, lng, label in zip(df_city['lat'], df_city['long'], df_city['City']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(city_map) 
    
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3511083b5611a1d72e3b1aa499b6129 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3511083b5611a1d72e3b1aa499b6129&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3511083b5611a1d72e3b1aa499b6129 = L.map(
#                 &quot;map_d3511083b5611a1d72e3b1aa499b6129&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_351c9f799226bd17d6040fa88f44df2c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3511083b5611a1d72e3b1aa499b6129);
#
#
#             var circle_marker_15482d0da352d1edf5ed810a6c977a4e = L.circleMarker(
#                 [52.5170365, 13.3888599],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d3511083b5611a1d72e3b1aa499b6129);
#
#
#         var popup_479645df1c839353a24db79045240396 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2f7e670a33515471a4dac6a5a828c1f = $(`&lt;div id=&quot;html_d2f7e670a33515471a4dac6a5a828c1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_479645df1c839353a24db79045240396.setContent(html_d2f7e670a33515471a4dac6a5a828c1f);
#
#
#
#         circle_marker_15482d0da352d1edf5ed810a6c977a4e.bindPopup(popup_479645df1c839353a24db79045240396)
#         ;
#
#
#
#
#             var circle_marker_427ab3c8e7db08503e61ba73dedd3164 = L.circleMarker(
#                 [55.001251, -115.002136],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d3511083b5611a1d72e3b1aa499b6129);
#
#
#         var popup_1572906a8d8eef272783c4b6d57a265f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dec52118fdddae82156cb89cfcd02df = $(`&lt;div id=&quot;html_1dec52118fdddae82156cb89cfcd02df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alberta&lt;/div&gt;`)[0];
#                 popup_1572906a8d8eef272783c4b6d57a265f.setContent(html_1dec52118fdddae82156cb89cfcd02df);
#
#
#
#         circle_marker_427ab3c8e7db08503e61ba73dedd3164.bindPopup(popup_1572906a8d8eef272783c4b6d57a265f)
#         ;
#
#
#
#
#             var circle_marker_e10cc086a84f810c96feac72e0ff8aa9 = L.circleMarker(
#                 [29.9759983, -90.0782127],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d3511083b5611a1d72e3b1aa499b6129);
#
#
#         var popup_8df76e3857a3e4e73fc68b9af5d8295c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dee6090a47197df9d45c92c297e9ffe4 = $(`&lt;div id=&quot;html_dee6090a47197df9d45c92c297e9ffe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Orleans&lt;/div&gt;`)[0];
#                 popup_8df76e3857a3e4e73fc68b9af5d8295c.setContent(html_dee6090a47197df9d45c92c297e9ffe4);
#
#
#
#         circle_marker_e10cc086a84f810c96feac72e0ff8aa9.bindPopup(popup_8df76e3857a3e4e73fc68b9af5d8295c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def generate_map (city, zoom):

    map = folium.Map(location=[df_city.loc[df_city['City']==city,'lat'].values[0],df_city.loc[df_city['City']==city,'long'].values[0]], zoom_start=zoom)
    #add markers to the cities
    for lat, lng, label in zip(df.loc[df['City']==city,'Latitude'], df.loc[df['City']==city,'Longitude'], df.loc[df['City']==city, 'Neighbourhood']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7).add_to(map)

    return map

# %%
map_berlin = generate_map('Berlin', 8)
map_berlin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_661041083b342af98e96e64043b968be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_661041083b342af98e96e64043b968be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_661041083b342af98e96e64043b968be = L.map(
#                 &quot;map_661041083b342af98e96e64043b968be&quot;,
#                 {
#                     center: [52.5170365, 13.3888599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d535e6d167f54cf104826e3220a87e29 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_661041083b342af98e96e64043b968be);
#
#
#             var circle_marker_60f9d9ad1a382c2eed1c013da4dcbd0f = L.circleMarker(
#                 [52.5078558, 13.2639518],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_661041083b342af98e96e64043b968be);
#
#
#         var popup_50e683164132ba237f99094057c96b5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b3bf22ae7adc0e959117b718bdf5253 = $(`&lt;div id=&quot;html_9b3bf22ae7adc0e959117b718bdf5253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Charlottenburg-Wilmersdorf&lt;/div&gt;`)[0];
#                 popup_50e683164132ba237f99094057c96b5f.setContent(html_9b3bf22ae7adc0e959117b718bdf5253);
#
#
#
#         circle_marker_60f9d9ad1a382c2eed1c013da4dcbd0f.bindPopup(popup_50e683164132ba237f99094057c96b5f)
#         ;
#
#
#
#
#             var circle_marker_3de33e9ffeae9e2073c041a76cefc657 = L.circleMarker(
#                 [52.5011154, 13.4442848],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_661041083b342af98e96e64043b968be);
#
#
#         var popup_31dd055253c536689b97af6df3fb3270 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d72d2c283af198b3e5ded79ffe859611 = $(`&lt;div id=&quot;html_d72d2c283af198b3e5ded79ffe859611&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Friedrichshain-Kreuzberg&lt;/div&gt;`)[0];
#                 popup_31dd055253c536689b97af6df3fb3270.setContent(html_d72d2c283af198b3e5ded79ffe859611);
#
#
#
#         circle_marker_3de33e9ffeae9e2073c041a76cefc657.bindPopup(popup_31dd055253c536689b97af6df3fb3270)
#         ;
#
#
#
#
#             var circle_marker_f43421e2672b95b6dedf6e04e82a0f92 = L.circleMarker(
#                 [52.5321606, 13.5118927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_661041083b342af98e96e64043b968be);
#
#
#         var popup_fb89f3d4c784d5bfe3cfc86e78227b09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c61bd785f5890aaffe933766ac9b8730 = $(`&lt;div id=&quot;html_c61bd785f5890aaffe933766ac9b8730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lichtenberg&lt;/div&gt;`)[0];
#                 popup_fb89f3d4c784d5bfe3cfc86e78227b09.setContent(html_c61bd785f5890aaffe933766ac9b8730);
#
#
#
#         circle_marker_f43421e2672b95b6dedf6e04e82a0f92.bindPopup(popup_fb89f3d4c784d5bfe3cfc86e78227b09)
#         ;
#
#
#
#
#             var circle_marker_a217d7c33e5acbd8bc5213848c3803cf = L.circleMarker(
#                 [52.5225225, 13.5876634],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffse

# %%
map_alberta = generate_map('Alberta', 3)
map_alberta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18bf8ac844b0054f9f960bba92189f8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18bf8ac844b0054f9f960bba92189f8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18bf8ac844b0054f9f960bba92189f8d = L.map(
#                 &quot;map_18bf8ac844b0054f9f960bba92189f8d&quot;,
#                 {
#                     center: [55.001251, -115.002136],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfb0bb1bfd0bc57806febe4334c9b45a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_18bf8ac844b0054f9f960bba92189f8d);
#
#
#             var circle_marker_040a8721072eaa2b758c83a64f989ff9 = L.circleMarker(
#                 [52.2474233, -113.7833343868671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18bf8ac844b0054f9f960bba92189f8d);
#
#
#         var popup_88be489e792405be694975cb0180e3f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a007ec66a6fba0cbaa34af33f71863db = $(`&lt;div id=&quot;html_a007ec66a6fba0cbaa34af33f71863db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anders Park&lt;/div&gt;`)[0];
#                 popup_88be489e792405be694975cb0180e3f6.setContent(html_a007ec66a6fba0cbaa34af33f71863db);
#
#
#
#         circle_marker_040a8721072eaa2b758c83a64f989ff9.bindPopup(popup_88be489e792405be694975cb0180e3f6)
#         ;
#
#
#
#
#             var circle_marker_cfbb993635ec432d9565b15abb04020a = L.circleMarker(
#                 [53.2165798, 6.5968342],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18bf8ac844b0054f9f960bba92189f8d);
#
#
#         var popup_adb562ff18a9422ad1bf9e62975e13e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30f40ed47b53578b2f4fdfaceba12915 = $(`&lt;div id=&quot;html_30f40ed47b53578b2f4fdfaceba12915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anders South&lt;/div&gt;`)[0];
#                 popup_adb562ff18a9422ad1bf9e62975e13e1.setContent(html_30f40ed47b53578b2f4fdfaceba12915);
#
#
#
#         circle_marker_cfbb993635ec432d9565b15abb04020a.bindPopup(popup_adb562ff18a9422ad1bf9e62975e13e1)
#         ;
#
#
#
#
#             var circle_marker_5bc738d545104de66c2a656d429e409c = L.circleMarker(
#                 [52.2382769, -113.77087407527756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_18bf8ac844b0054f9f960bba92189f8d);
#
#
#         var popup_c748e061e07fc6d988da173426af2b1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e4552a0e951d07db38bdbbfff3964e7 = $(`&lt;div id=&quot;html_6e4552a0e951d07db38bdbbfff3964e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aspen Ridge&lt;/div&gt;`)[0];
#                 popup_c748e061e07fc6d988da173426af2b1d.setContent(html_6e4552a0e951d07db38bdbbfff3964e7);
#
#
#
#         circle_marker_5bc738d545104de66c2a656d429e409c.bindPopup(popup_c748e061e07fc6d988da173426af2b1d)
#         ;
#
#
#
#
#             var circle_marker_726af929ddd52794e7c01952471484c4 = L.circleMarker(
#                 [52.24037425, -113.81273306719862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset

# %% [markdown]
# ## Outlaier in Canada

# %%
more_50 = df.loc[(df['Country']=='Canada') & (df['Latitude']<50)]
canada_outlaier =more_50.loc[(more_50['Country']=='Canada') & (more_50['Longitude']<-77)]
canada_outlaier
# Out:
#                       Neighbourhood     City Country   Latitude   Longitude
# 18              Clearview Extension  Alberta  Canada  40.637421  -80.065206
# 19                Clearview Meadows  Alberta  Canada  44.427220  -80.095086
# 23                Deer Park Estates  Alberta  Canada  43.182807  -79.530590
# 24                Deer Park Village  Alberta  Canada  49.243310 -123.003170
# 27                  East Burnt Lake  Alberta  Canada  42.130296 -120.199573
# 36            Glendale Park Estates  Alberta  Canada  33.539926 -112.241820
# 41           Highland Green Estates  Alberta  Canada  30.532227  -91.103417
# 45                   Johnstone Park  Alberta  Canada  43.702106  -79.808934
# 46                    Kentwood East  Alberta  Canada  35.958391  -83.583009
# 52                         Lonsdale  Alberta  Canada  44.275362  -77.126668
# 54   McKenzie Trail Recreation Area  Alberta  Canada  48.104745 -103.103519
# 56                        Morrisroe  Alberta  Canada  34.133236 -118.127660
# 61                 Oriole Park West  Alberta  Canada  49.847391 -119.674071
# 69  Riverside Light Industrial Park  Alberta  Canada  25.044569  -77.331468
# 72                 Rosedale Meadows  Alberta  Canada  42.357584  -83.356985
# 73                       South Hill  Alberta  Canada  43.677926  -79.405767
# 76             Sunnybrook Extension  Alberta  Canada  43.722800  -79.372900

# %%
df.drop(index=canada_outlaier.index,inplace=True)

# %%
map_alberta = generate_map('Alberta', 3)
map_alberta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed99f4b8e3b713b8033081334c85fd7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed99f4b8e3b713b8033081334c85fd7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed99f4b8e3b713b8033081334c85fd7a = L.map(
#                 &quot;map_ed99f4b8e3b713b8033081334c85fd7a&quot;,
#                 {
#                     center: [55.001251, -115.002136],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62285985b712f5b2202c1820dc713ff3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed99f4b8e3b713b8033081334c85fd7a);
#
#
#             var circle_marker_f5205c5f4566800bdeb981ca54542685 = L.circleMarker(
#                 [52.2474233, -113.7833343868671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed99f4b8e3b713b8033081334c85fd7a);
#
#
#         var popup_7ff970033ee4f3637cbb89f3a23a6b82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c498470e8eae96dbb975406cee0f7258 = $(`&lt;div id=&quot;html_c498470e8eae96dbb975406cee0f7258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anders Park&lt;/div&gt;`)[0];
#                 popup_7ff970033ee4f3637cbb89f3a23a6b82.setContent(html_c498470e8eae96dbb975406cee0f7258);
#
#
#
#         circle_marker_f5205c5f4566800bdeb981ca54542685.bindPopup(popup_7ff970033ee4f3637cbb89f3a23a6b82)
#         ;
#
#
#
#
#             var circle_marker_95e87f0f4111299141d6550e49b173c8 = L.circleMarker(
#                 [53.2165798, 6.5968342],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed99f4b8e3b713b8033081334c85fd7a);
#
#
#         var popup_8f38e25550df15caf5bb1824654b7cdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75c746fb54a91b2e93f268747c44570f = $(`&lt;div id=&quot;html_75c746fb54a91b2e93f268747c44570f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anders South&lt;/div&gt;`)[0];
#                 popup_8f38e25550df15caf5bb1824654b7cdb.setContent(html_75c746fb54a91b2e93f268747c44570f);
#
#
#
#         circle_marker_95e87f0f4111299141d6550e49b173c8.bindPopup(popup_8f38e25550df15caf5bb1824654b7cdb)
#         ;
#
#
#
#
#             var circle_marker_fb6fa601570a184cae4d4361f272f9a8 = L.circleMarker(
#                 [52.2382769, -113.77087407527756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed99f4b8e3b713b8033081334c85fd7a);
#
#
#         var popup_a07b1b45fcbbf4e8fb9d024f99996dfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd13b86c8c3dd8495fcd7e83e1913791 = $(`&lt;div id=&quot;html_bd13b86c8c3dd8495fcd7e83e1913791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aspen Ridge&lt;/div&gt;`)[0];
#                 popup_a07b1b45fcbbf4e8fb9d024f99996dfd.setContent(html_bd13b86c8c3dd8495fcd7e83e1913791);
#
#
#
#         circle_marker_fb6fa601570a184cae4d4361f272f9a8.bindPopup(popup_a07b1b45fcbbf4e8fb9d024f99996dfd)
#         ;
#
#
#
#
#             var circle_marker_f78148fc81f8f29b2663a93fb4a51288 = L.circleMarker(
#                 [52.24037425, -113.81273306719862],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset

# %%
map_alberta = generate_map('New Orleans', 3)
map_alberta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c5c4240a7fdfdbf4e38e46b6c022c75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c5c4240a7fdfdbf4e38e46b6c022c75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c5c4240a7fdfdbf4e38e46b6c022c75 = L.map(
#                 &quot;map_3c5c4240a7fdfdbf4e38e46b6c022c75&quot;,
#                 {
#                     center: [29.9759983, -90.0782127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae08c81c5cda89bef02f6f73ded79e8f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c5c4240a7fdfdbf4e38e46b6c022c75);
#
#
#             var circle_marker_355e4ea933f7c3932a88444d92142e16 = L.circleMarker(
#                 [41.34363695, -72.09348643841241],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3c5c4240a7fdfdbf4e38e46b6c022c75);
#
#
#         var popup_24ce54c14cae7a22a59df9b8d6cbe8ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c0277a7689b6908b1c3096a1ebfd5d9 = $(`&lt;div id=&quot;html_4c0277a7689b6908b1c3096a1ebfd5d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U.S. NAVAL BASE&lt;/div&gt;`)[0];
#                 popup_24ce54c14cae7a22a59df9b8d6cbe8ce.setContent(html_4c0277a7689b6908b1c3096a1ebfd5d9);
#
#
#
#         circle_marker_355e4ea933f7c3932a88444d92142e16.bindPopup(popup_24ce54c14cae7a22a59df9b8d6cbe8ce)
#         ;
#
#
#
#
#             var circle_marker_a6befcbcab73ce55e74978d770fef252 = L.circleMarker(
#                 [29.95251, -90.0517746],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3c5c4240a7fdfdbf4e38e46b6c022c75);
#
#
#         var popup_256e4b4c92e22761db38de44e68a0349 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7de0abdcf222125ab2835d1a74963ec = $(`&lt;div id=&quot;html_e7de0abdcf222125ab2835d1a74963ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ALGIERS POINT&lt;/div&gt;`)[0];
#                 popup_256e4b4c92e22761db38de44e68a0349.setContent(html_e7de0abdcf222125ab2835d1a74963ec);
#
#
#
#         circle_marker_a6befcbcab73ce55e74978d770fef252.bindPopup(popup_256e4b4c92e22761db38de44e68a0349)
#         ;
#
#
#
#
#             var circle_marker_3acfd2a6771f72757593265d84d19f5f = L.circleMarker(
#                 [29.9692573, -90.05151248529518],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3c5c4240a7fdfdbf4e38e46b6c022c75);
#
#
#         var popup_52f734c35284d4fba8f775c066dea453 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7453785da85ff3c000b9a74c16d926f = $(`&lt;div id=&quot;html_e7453785da85ff3c000b9a74c16d926f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WHITNEY&lt;/div&gt;`)[0];
#                 popup_52f734c35284d4fba8f775c066dea453.setContent(html_e7453785da85ff3c000b9a74c16d926f);
#
#
#
#         circle_marker_3acfd2a6771f72757593265d84d19f5f.bindPopup(popup_52f734c35284d4fba8f775c066dea453)
#         ;
#
#
#
#
#             var circle_marker_cd8e3245f663a84ca590ec39ef402d0b = L.circleMarker(
#                 [29.9222962, -90.13067671260173],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset

# %% [markdown]
# ## Outlaier in US

# %%
out=df.loc[df.Neighbourhood.isin(['VILLAGE DE LEST','ST. THOMAS DEV'])]

# %%
df.drop(index=out.index,inplace=True)

# %%
map_alberta = generate_map('New Orleans', 3)
map_alberta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ae558634c39fc5e01630515a43c58ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ae558634c39fc5e01630515a43c58ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ae558634c39fc5e01630515a43c58ca = L.map(
#                 &quot;map_4ae558634c39fc5e01630515a43c58ca&quot;,
#                 {
#                     center: [29.9759983, -90.0782127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38119a8c3c9bc96afb8e4103730b1b74 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ae558634c39fc5e01630515a43c58ca);
#
#
#             var circle_marker_cd15440917a83fcd193548e4823a1839 = L.circleMarker(
#                 [41.34363695, -72.09348643841241],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ae558634c39fc5e01630515a43c58ca);
#
#
#         var popup_1fa8cd1f9fe15d4e572ccb05023bcf07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c242e29ffd3166605947b24360b5ea1 = $(`&lt;div id=&quot;html_9c242e29ffd3166605947b24360b5ea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;U.S. NAVAL BASE&lt;/div&gt;`)[0];
#                 popup_1fa8cd1f9fe15d4e572ccb05023bcf07.setContent(html_9c242e29ffd3166605947b24360b5ea1);
#
#
#
#         circle_marker_cd15440917a83fcd193548e4823a1839.bindPopup(popup_1fa8cd1f9fe15d4e572ccb05023bcf07)
#         ;
#
#
#
#
#             var circle_marker_3e6c0b0edffa12ad752f5cf12a99a34b = L.circleMarker(
#                 [29.95251, -90.0517746],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ae558634c39fc5e01630515a43c58ca);
#
#
#         var popup_991c01b4b4462b3fbbacbd249716ceaa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5b884d9954cc29feed61b617c59c04b = $(`&lt;div id=&quot;html_b5b884d9954cc29feed61b617c59c04b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ALGIERS POINT&lt;/div&gt;`)[0];
#                 popup_991c01b4b4462b3fbbacbd249716ceaa.setContent(html_b5b884d9954cc29feed61b617c59c04b);
#
#
#
#         circle_marker_3e6c0b0edffa12ad752f5cf12a99a34b.bindPopup(popup_991c01b4b4462b3fbbacbd249716ceaa)
#         ;
#
#
#
#
#             var circle_marker_21eddd115bf61c45c2002f92ddce2d39 = L.circleMarker(
#                 [29.9692573, -90.05151248529518],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4ae558634c39fc5e01630515a43c58ca);
#
#
#         var popup_20ec366cb222cde10028c2959b60a1ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24e41dca545dfb608c7f30c2a028fc3a = $(`&lt;div id=&quot;html_24e41dca545dfb608c7f30c2a028fc3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WHITNEY&lt;/div&gt;`)[0];
#                 popup_20ec366cb222cde10028c2959b60a1ff.setContent(html_24e41dca545dfb608c7f30c2a028fc3a);
#
#
#
#         circle_marker_21eddd115bf61c45c2002f92ddce2d39.bindPopup(popup_20ec366cb222cde10028c2959b60a1ff)
#         ;
#
#
#
#
#             var circle_marker_f32a7cc5d2a6c4fcd0f8d16c65941a3b = L.circleMarker(
#                 [29.9222962, -90.13067671260173],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset
